# %% [markdown]
# # Writing in notebook
#
# Would not it be *great* if most of the material could be written in [jupyter notebook](http://jupyter.org)?
#
# Well, now that's possible with the help of **nbsphinx** extension

# %%
# %pylab inline

a = rand(200)-0.5
plot(cumsum(a))
# Out:
# Populating the interactive namespace from numpy and matplotlib
